# %% [markdown]
#  # culate MAE, MSE, RMSE, R square
#  # 1st ation (price output and km input)
#
# # 2 equation (price output and mileage as inputs)
#
# # 3 equation (price output and (mileage and km inputs)
#
#
# # lculate MAE, MSE, RMSE, R square

# %%
#1st equation

import pandas as pd
import numpy as np
data=pd.read_csv(r"C:\Users\DELL\Desktop\used cars.csv")
data
# Out:
#       kms_driven  mileage(kmpl)  engine(cc)  max_power(bhp)  torque(Nm)  \
# 0          56000           7.81      2996.0          2996.0       333.0
# 1          30615          17.40       999.0           999.0      9863.0
# 2          24000          20.68      1995.0          1995.0       188.0
# 3          18378          16.50      1353.0          1353.0     13808.0
# 4          44900          14.67      1798.0          1798.0     17746.0
# ...          ...            ...         ...             ...         ...
# 1548       35000        1493.00     11345.0         11345.0       250.0
# 1549       10000         999.00      6706.0          6706.0        91.0
# 1550       49000          17.50      1199.0          1199.0       887.0
# 1551       40000          18.78       999.0           999.0        75.0
# 1552       34756          20.85      1197.0          1197.0      8314.0
#
#       price(in lakhs)
# 0               63.75
# 1                8.99
# 2               23.75
# ...

# %%
x= data.drop(['price(in lakhs)','mileage(kmpl)','engine(cc)','max_power(bhp)','torque(Nm)'], axis='columns')
data
# Out:
#       kms_driven  mileage(kmpl)  engine(cc)  max_power(bhp)  torque(Nm)  \
# 0          56000           7.81      2996.0          2996.0       333.0
# 1          30615          17.40       999.0           999.0      9863.0
# 2          24000          20.68      1995.0          1995.0       188.0
# 3          18378          16.50      1353.0          1353.0     13808.0
# 4          44900          14.67      1798.0          1798.0     17746.0
# ...          ...            ...         ...             ...         ...
# 1548       35000        1493.00     11345.0         11345.0       250.0
# 1549       10000         999.00      6706.0          6706.0        91.0
# 1550       49000          17.50      1199.0          1199.0       887.0
# 1551       40000          18.78       999.0           999.0        75.0
# 1552       34756          20.85      1197.0          1197.0      8314.0
#
#       price(in lakhs)
# 0               63.75
# 1                8.99
# 2               23.75
# ...

# %%
y= data.drop(['kms_driven','mileage(kmpl)','engine(cc)','max_power(bhp)','torque(Nm)'], axis='columns')

# %%
data
# Out:
#       kms_driven  mileage(kmpl)  engine(cc)  max_power(bhp)  torque(Nm)  \
# 0          56000           7.81      2996.0          2996.0       333.0
# 1          30615          17.40       999.0           999.0      9863.0
# 2          24000          20.68      1995.0          1995.0       188.0
# 3          18378          16.50      1353.0          1353.0     13808.0
# 4          44900          14.67      1798.0          1798.0     17746.0
# ...          ...            ...         ...             ...         ...
# 1548       35000        1493.00     11345.0         11345.0       250.0
# 1549       10000         999.00      6706.0          6706.0        91.0
# 1550       49000          17.50      1199.0          1199.0       887.0
# 1551       40000          18.78       999.0           999.0        75.0
# 1552       34756          20.85      1197.0          1197.0      8314.0
#
#       price(in lakhs)
# 0               63.75
# 1                8.99
# 2               23.75
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.5,random_state=1)
print(x_train)
print(y_train)
print(x_test)
print(y_test)
# Out:
#       kms_driven
# 295        65170
# 1064       60000
# 474        26000
# 810        30300
# 472        19000
# ...          ...
# 715        11000
# 905        11000
# 1096      104000
# 235        32000
# 1061       31655
#
# [776 rows x 1 columns]
#       price(in lakhs)
# 295              3.02
# 1064             1.75
# 474              7.95
# 810             24.80
# 472             78.99
# ...               ...
# 715             50.00
# 905             66.00
# 1096             5.25
# 235             18.20
# 1061             7.75
#
# [776 rows x 1 columns]
#       kms_driven
# 774        61383
# 396        16000
# 1297       44000
# 647        51000
# 491         9000
# ...          ...
# 164        62700
# 486        11000
# 1203       39458
# 1087       40000
# 1141      104255
#
# [777 rows x 1 columns]
#       price(in lakhs)
# 774              9.63
# 396             83.00
# 1297             5.50
# 647             21.00
# 491             70.00
# ...               ...
# ...

# %%
equation=LinearRegression()
equation.fit(x_train,y_train)
print(equation.intercept_)
print(equation.coef_)
# Out:
# [226.37866614]
# [[0.00176398]]

# %%
y_test_predicted=equation.predict(x_test)
print(y_test_predicted)
# Out:
# [[ 334.65722916]
#  [ 254.60239271]
#  [ 303.99391422]
#  [ 316.34179459]
#  [ 242.25451234]
#  [ 314.57781168]
#  [ 309.28586295]
#  [ 312.00063265]
#  [ 244.51241046]
#  [ 358.67738445]
#  [ 303.08899098]
#  [ 263.18593356]
#  [ 271.36023037]
#  [ 286.81272066]
#  [ 256.09648624]
#  [ 312.71857369]
#  [ 396.88172633]
#  [ 308.06871474]
#  [ 358.67738445]
#  [ 302.7467783 ]
#  [ 288.11806802]
#  [ 353.62357341]
#  [ 303.99391422]
#  [ 282.82611929]
#  [ 288.11806802]
#  [ 386.15318227]
#  [ 272.40450825]
#  [ 279.29815346]
#  [ 314.87768878]
#  [ 312.81382877]
#  [ 314.57781168]
#  [ 349.8574699 ]
#  [ 304.02566591]
#  [1655.20482392]
#  [ 347.20973155]
#  [ 315.58328194]
#  [ 279.29815346]
#  [ 373.38370998]
#  [ 305.75789713]
#  [ 300.46594839]
#  [ 261.65832436]
#  [ 256.43869892]
#  [ 282.82611929]
#  [ 265.18629018]
#  [ 358.67738445]
#  [ 228.14264905]
#  [ 379.84517938]
#  [ 318.1057775 ]
#  [ 402.77695722]
#  [ 440.31627755]
#  [ 303.99391422]
#  [ 363.41191458]
# ...

# %%
from sklearn import metrics
MAE=metrics.mean_absolute_error(y_test,y_test_predicted)
print(MAE)

MSE=metrics.mean_squared_error(y_test,y_test_predicted)
print(MSE)

RMSE=np.sqrt(metrics.mean_squared_error(y_test,y_test_predicted))
print(RMSE)

R2=metrics.r2_score(y_test,y_test_predicted)
print(R2)
# Out:
# 306.7013817672005
# 102097.29780559748
# 319.5266777682225
# -306.93102322291924

# %%
import matplotlib.pyplot as plt                                  
import seaborn as sns 
sns.regplot(x=x_test, y=y_test_predicted)
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
# Out:
# Text(0, 0.5, 'Predicted Values')

# %%
#2nd equation

x= data.drop(['price(in lakhs)','kms_driven','engine(cc)','max_power(bhp)','torque(Nm)'], axis='columns')
data
# Out:
#       kms_driven  mileage(kmpl)  engine(cc)  max_power(bhp)  torque(Nm)  \
# 0          56000           7.81      2996.0          2996.0       333.0
# 1          30615          17.40       999.0           999.0      9863.0
# 2          24000          20.68      1995.0          1995.0       188.0
# 3          18378          16.50      1353.0          1353.0     13808.0
# 4          44900          14.67      1798.0          1798.0     17746.0
# ...          ...            ...         ...             ...         ...
# 1548       35000        1493.00     11345.0         11345.0       250.0
# 1549       10000         999.00      6706.0          6706.0        91.0
# 1550       49000          17.50      1199.0          1199.0       887.0
# 1551       40000          18.78       999.0           999.0        75.0
# 1552       34756          20.85      1197.0          1197.0      8314.0
#
#       price(in lakhs)
# 0               63.75
# 1                8.99
# 2               23.75
# ...

# %%
y=data.drop(['kms_driven','mileage(kmpl)','engine(cc)','max_power(bhp)','torque(Nm)'],axis='columns')
data
# Out:
#       kms_driven  mileage(kmpl)  engine(cc)  max_power(bhp)  torque(Nm)  \
# 0          56000           7.81      2996.0          2996.0       333.0
# 1          30615          17.40       999.0           999.0      9863.0
# 2          24000          20.68      1995.0          1995.0       188.0
# 3          18378          16.50      1353.0          1353.0     13808.0
# 4          44900          14.67      1798.0          1798.0     17746.0
# ...          ...            ...         ...             ...         ...
# 1548       35000        1493.00     11345.0         11345.0       250.0
# 1549       10000         999.00      6706.0          6706.0        91.0
# 1550       49000          17.50      1199.0          1199.0       887.0
# 1551       40000          18.78       999.0           999.0        75.0
# 1552       34756          20.85      1197.0          1197.0      8314.0
#
#       price(in lakhs)
# 0               63.75
# 1                8.99
# 2               23.75
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.45,random_state=1)

print(x_train)
print(y_train)
print(x_test)
print(y_test)
# Out:
#       mileage(kmpl)
# 1409          14.67
# 1201         796.00
# 680           20.52
# 1134          18.50
# 367         1497.00
# ...             ...
# 715           15.00
# 905           18.80
# 1096          23.59
# 235         1995.00
# 1061          22.38
#
# [854 rows x 1 columns]
#       price(in lakhs)
# 1409            10.95
# 1201             4.20
# 680              5.75
# 1134             4.50
# 367              3.50
# ...               ...
# 715             50.00
# 905             66.00
# 1096             5.25
# 235             18.20
# 1061             7.75
#
# [854 rows x 1 columns]
#       mileage(kmpl)
# 774           18.15
# 396         2996.00
# 1297          26.00
# 647           13.70
# 491           12.10
# ...             ...
# 906           17.00
# 72            11.30
# 257          998.00
# 1035          17.99
# 2             20.68
#
# [699 rows x 1 columns]
#       price(in lakhs)
# 774              9.63
# 396             83.00
# 1297             5.50
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
equation=LinearRegression()
equation.fit(x_train,y_train)
print(equation.intercept_)
print(equation.coef_)
y_test_predicted=equation.predict(x_test)
print(y_test_predicted)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[81], line 2
#       1 equation=LinearRegression()
# ----> 2 equation.fit(x_train,y_train)
#       3 print(equation.intercept_)
#       4 print(equation.coef_)
#
# File D:\Anaconda\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File D:\Anaconda\Lib\site-packages\sklearn\linear_model\_base.py:678, in LinearRegression.fit(self, X, y, sample_weight)
#     674 n_jobs_ = self.n_jobs
#     676 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# ...
